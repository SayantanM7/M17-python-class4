# %% [markdown]
# **Square root**

# %%
n= int(input("Enter a number you want to find the square root of "))
sq= n**(1/2)
print(f"The square root of {n} is {sq}")
# Out:
# Enter a number you want to find the square root of  121
# The square root of 121 is 11.0
